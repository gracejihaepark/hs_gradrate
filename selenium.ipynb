# %%
#all public high schools in nyc
https://data.nysed.gov/profile.php?instid=7889678368

# %%
from selenium import webdriver

# %%
chrome_path = r'/Users/ruthmazurek/Downloads/chromedriver'

# %%
driver = webdriver.Chrome(chrome_path)

# %%
driver.get('https://data.nysed.gov/profile.php?instid=7889678368')

# %%
districts = driver.find_elements_by_class_name('bullet-item').click()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-7b5127223622> in <module>
# ----> 1 districts = driver.find_elements_by_class_name('bullet-item').click()
#
# AttributeError: 'list' object has no attribute 'click'

# %%
driver.page_source
# Out:
# '<html class=" js flexbox flexboxlegacy canvas canvastext webgl no-touch geolocation postmessage websqldatabase indexeddb hashchange history draganddrop websockets rgba hsla multiplebgs backgroundsize borderimage borderradius boxshadow textshadow opacity cssanimations csscolumns cssgradients cssreflections csstransforms csstransforms3d csstransitions fontface generatedcontent video audio localstorage sessionstorage webworkers applicationcache svg inlinesvg smil svgclippaths" lang="en" style="height: 100%;"><head><script type="text/javascript" async="" src="https://www.google-analytics.com/plugins/ua/linkid.js"></script><script type="text/javascript" src="https://m.addthis.com/live/red_lojson/300lo.json?si=5e1cb9bfd3f9bfb0&amp;bkl=0&amp;bl=1&amp;pdt=548&amp;sid=5e1cb9bfd3f9bfb0&amp;pub=ra-4ee0cca1405f20a5&amp;rev=v8.28.1-wp&amp;ln=en&amp;pc=men&amp;cb=0&amp;ab=-&amp;dp=data.nysed.gov&amp;fp=profile.php%3Finstid%3D7889678368&amp;fr=&amp;of=2&amp;pd=0&amp;irt=0&amp;vcl=0&amp;md=0&amp;ct
# ...
